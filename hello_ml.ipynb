# %%
print("Hello, Machine Learning!")
# Out:
# Hello, Machine Learning!

# %% [markdown]
# # Hello Machine Learning
#
# This is my first Jupyter Notebook for the Classic Machine Learning course. I am learning how to use notebooks and GitHub to document and share machine learning work.
